# %% [markdown]
# ## Intro
# This is a simple ETL (extract, transform, load) job for Messier object data. The data are obtained from three sources:
# 1. The full Messier catalogue from http://www.klima-luft.de/steinicke/ngcic/ngcic_e.htm
# 1. Additional laymen data from Wikipedia
# 1. Images of the Messier objects from Wikipedia
#
# The files are uploaded to GitHub as examples for the processing. Future ETL jobs with other DSOs, exoplanets, and eclipsing binaries will be handled without the examples.

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %% [markdown]
# ### Extract

# %%
messier_df = pd.read_excel('raw_data/Historic_M.xls') 
cons_df = pd.read_excel('raw_data/list-constellations-677j.xls', usecols="B,C") 
data = pd.read_csv("raw_data/wiki_m.csv") 
add_df = data[["NGC/IC number", "Common name", "Object type"]]

# %%
html = urlopen('https://en.wikipedia.org/wiki/Messier_object')
bs = BeautifulSoup(html, 'html.parser')
images = bs.find_all('img', {'src':re.compile('.jpg')})

# %% [markdown]
# ### Transform

# %%
messier_df["name"] = "Messier " + messier_df["M"].map(str)
messier_df["params"] = "m" + messier_df["M"].map(str)
messier_df["ra"] = messier_df["RH"].map(str) + "h"+ messier_df["RM"].map(str) + "m" + messier_df["RS"].map(str) + "s"
messier_df["dec"] = messier_df["V"].map(str) + messier_df["DG"].map(str) + "d"+ messier_df["DM"].map(str) + "m" + messier_df["DS"].map(str) + "s"
del messier_df['M']
del messier_df['RH']
del messier_df['RM']
del messier_df['RS']
del messier_df['DG']
del messier_df['DM']
del messier_df['DS']
del messier_df['C']
del messier_df['N']
del messier_df['NI']
del messier_df['Class']
del messier_df['h']
del messier_df['GC']
del messier_df['Other']
del messier_df['Discoverer']
del messier_df['Y']
del messier_df['M.1']
del messier_df['D']
del messier_df['Ap']
del messier_df['T']
del messier_df['Observer1']
del messier_df['Observer2']
del messier_df['V']
del messier_df['Remarks']
del messier_df['S']
del messier_df['Type']
messier_df.rename({"Dist (kly)": "dist", "Vmag": "mag"}, axis=1, inplace=True)

messier_df.head()
# Out:
#    Con  dist  mag       name params           ra         dec
# 0  TAU   6.5  8.4  Messier 1     m1   5h34m31.9s   +22d0m52s
# 1  AQR  33.0  6.6  Messier 2     m2  21h33m27.2s   -0d49m22s
# 2  CVN  33.9  6.3  Messier 3     m3  13h42m11.2s  +28d22m34s
# 3  SCO   7.2  5.4  Messier 4     m4  16h23m35.5s  -26d31m29s
# 4  SER  24.5  5.7  Messier 5     m5  15h18m33.8s     +2d5m0s

# %%
for i in range(len(messier_df["Con"])):
    for j in range(len(cons_df["Abbreviation"])):
        if messier_df["Con"][i] == cons_df["Abbreviation"][j].upper():
            messier_df["Con"][i] = cons_df["Constellation"][j]
            
messier_df.head()
# Out:
# /var/folders/qp/9vkptzrj44z9f5y8mt7k96dr0000gn/T/ipykernel_73269/1800166425.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   messier_df["Con"][i] = cons_df["Constellation"][j]
#               Con  dist  mag       name params           ra         dec
# 0          Taurus   6.5  8.4  Messier 1     m1   5h34m31.9s   +22d0m52s
# 1        Aquarius  33.0  6.6  Messier 2     m2  21h33m27.2s   -0d49m22s
# 2  Canes Venatici  33.9  6.3  Messier 3     m3  13h42m11.2s  +28d22m34s
# 3        Scorpius   7.2  5.4  Messier 4     m4  16h23m35.5s  -26d31m29s
# 4         Serpens  24.5  5.7  Messier 5     m5  15h18m33.8s     +2d5m0s

# %%
check_galaxy = "galaxy"
check_emission = "H II"
check_asterism = "Star System"

for i in range(len(add_df["Object type"])):
    if add_df["Object type"][i].find(check_galaxy) != -1:
        add_df["Object type"][i] = "galaxy"
    if add_df["Object type"][i].find(check_emission) != -1:
        add_df["Object type"][i] = "emission nebula"
    if add_df["Object type"][i].find(check_asterism) != -1:
        add_df["Object type"][i] = "asterism"
    add_df["Object type"][i] = add_df["Object type"][i].lower()
# Out:
# /var/folders/qp/9vkptzrj44z9f5y8mt7k96dr0000gn/T/ipykernel_73269/1188317650.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_df["Object type"][i] = add_df["Object type"][i].lower()
# /var/folders/qp/9vkptzrj44z9f5y8mt7k96dr0000gn/T/ipykernel_73269/1188317650.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_df["Object type"][i] = "galaxy"

# %%
add_df["Common name"][16] = add_df["Common name"][16].replace(" or", "")
add_df["Common name"][32] = add_df["Common name"][32].replace("/", ", ")
add_df["Common name"][43] = add_df["Common name"][43].replace(" or", ",")
add_df["Common name"][73] = add_df["Common name"][73].replace("[91]", "")

add_df["Object type"][7] = add_df["Object type"][7].replace("Nebula with cluster", "emission nebula")
add_df["Object type"][23] = add_df["Object type"][23].replace("Milky Way star cloud", "star cloud")

add_df.head()
# Out:
# /var/folders/qp/9vkptzrj44z9f5y8mt7k96dr0000gn/T/ipykernel_73269/2387462411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_df["Common name"][16] = add_df["Common name"][16].replace(" or", "")
# /var/folders/qp/9vkptzrj44z9f5y8mt7k96dr0000gn/T/ipykernel_73269/2387462411.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_df["Common name"][32] = add_df["Common name"][32].replace("/", ", ")
# /var/folders/qp/9vkptzrj44z9f5y8mt7k96dr0000gn/T/ipykernel_73269/2387462411.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_df["Common name"][43] = add_df["Common name"][43].replace(" or", ",")
# /var/folders/qp/9vkptzrj44z9f5y8mt7k96dr0000gn/T/ipykernel_73269/2387462411.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_df["Common name"][73] = add_df["Common name"][73].replace("[91]", "")
# /var/folders/qp/9vkptzrj44z9f5y8mt7k96dr0000gn/T/ipykernel_73269/2387462411.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_df["Object type"][7] = add_df["Object type"][7].replace("Nebula with cluster", "emission nebula")
# /var/folders/qp/9vkptzrj44z9f5y8mt7k96dr0000gn/T/ipykernel_73269/2387462411.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_df["Object type"][23] = add_df["Object type"][23].replace("Milky Way star cloud", "star cloud")
#   NGC/IC number  Common name        Object type
# 0      NGC 1952  Crab Nebula  supernova remnant
# 1      NGC 7089            –   globular cluster
# 2      NGC 5272            –   globular cluster
# 3      NGC 6121            –   globular cluster
# 4      NGC 5904            –   globular cluster

# %%
full_messier = pd.concat([messier_df.reset_index(drop=True),add_df.reset_index(drop=True)],axis=1)
full_messier.rename({"NGC/IC number": "ngcic", "Common name": "common", "Object type": "type", "Con": "con"}, axis=1, inplace=True)
full_messier = full_messier[["params", "name", "ngcic", "common", "type", "ra", "dec", "mag", "dist", "con"]]
full_messier.head()
# Out:
#   params       name     ngcic       common               type           ra  \
# 0     m1  Messier 1  NGC 1952  Crab Nebula  supernova remnant   5h34m31.9s
# 1     m2  Messier 2  NGC 7089            –   globular cluster  21h33m27.2s
# 2     m3  Messier 3  NGC 5272            –   globular cluster  13h42m11.2s
# 3     m4  Messier 4  NGC 6121            –   globular cluster  16h23m35.5s
# 4     m5  Messier 5  NGC 5904            –   globular cluster  15h18m33.8s
#
#           dec  mag  dist             con
# 0   +22d0m52s  8.4   6.5          Taurus
# 1   -0d49m22s  6.6  33.0        Aquarius
# 2  +28d22m34s  6.3  33.9  Canes Venatici
# 3  -26d31m29s  5.4   7.2        Scorpius
# 4     +2d5m0s  5.7  24.5         Serpens

# %%
all_images = []

for image in images: 
    bigger_image = image['src'].replace("70px","500px").replace("//","")
    all_images.append("https://" + bigger_image)

all_images.pop()
all_images.pop(0)
all_images.pop(0)

all_images.insert(31,"https://upload.wikimedia.org/wikipedia/commons/thumb/c/cc/M32_Francione_inverted.jpg/200px-M32_Francione_inverted.jpg")
all_images.insert(56,"https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/M57_The_Ring_Nebula.JPG/200px-M57_The_Ring_Nebula.JPG")
all_images.insert(91,"https://upload.wikimedia.org/wikipedia/commons/thumb/1/1b/M92_Hubble_WikiSky.jpg/200px-M92_Hubble_WikiSky.jpg")
all_images.insert(101,"https://upload.wikimedia.org/wikipedia/commons/thumb/9/91/Ngc5866_hst_big.png/200px-Ngc5866_hst_big.png")

image_df = pd.DataFrame(all_images, columns =['image'])
image_df.head()
# Out:
#                                                image
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...

# %%
complete_messier = pd.concat([full_messier.reset_index(drop=True),image_df.reset_index(drop=True)],axis=1)
complete_messier.replace(',','', regex=True, inplace=True)
complete_messier
# Out:
#     params         name              ngcic  \
# 0       m1    Messier 1           NGC 1952
# 1       m2    Messier 2           NGC 7089
# 2       m3    Messier 3           NGC 5272
# 3       m4    Messier 4           NGC 6121
# 4       m5    Messier 5           NGC 5904
# 5       m6    Messier 6           NGC 6405
# 6       m7    Messier 7           NGC 6475
# 7       m8    Messier 8           NGC 6523
# 8       m9    Messier 9           NGC 6333
# 9      m10   Messier 10           NGC 6254
# 10     m11   Messier 11           NGC 6705
# 11     m12   Messier 12           NGC 6218
# 12     m13   Messier 13           NGC 6205
# 13     m14   Messier 14           NGC 6402
# 14     m15   Messier 15           NGC 7078
# 15     m16   Messier 16           NGC 6611
# 16     m17   Messier 17           NGC 6618
# 17     m18   Messier 18           NGC 6613
# 18     m19   Messier 19           NGC 6273
# 19     m20   Messier 20           NGC 6514
# 20     m21   Messier 21           NGC 6531
# 21     m22   Messier 22           NGC 6656
# 22     m23   Messier 23           NGC 6494
# 23     m24   Messier 24            IC 4715
# 24     m25   Messier 25            IC 4725
# 25     m26   Messier 26           NGC 6694
# 26     m27   Messier 27           NGC 6853
# 27     m28   Messier 28           NGC 6626
# 28     m29   Messier 29           NGC 6913
# 29     m30   Messier 30           NGC 7099
# 30     m31   Messier 31            NGC 224
# 31     m32   Messier 32            NGC 221
# 32     m33   Messier 33            NGC 598
# 33     m34   Messier 34           NGC 1039
# 34     m35   Messier 35           NGC 2168
# 35     m36   Messier 36           NGC 1960
# 36     m37   Messier 37           NGC 2099
# 37     m38   Messier 38           NGC 1912
# 38     m39   Messier 39           NGC 7092
# 39     m40   Messier 40                  –
# 40     m41   Messier 41           NGC 2287
# 41     m42   Messier 42           NGC 1976
# 42     m43   Messier 43           NGC 1982
# 43     m44   Messier 44           NGC 2632
# 44     m45   Messier 45                  –
# 45     m46   Messier 46           NGC 2437
# 46     m47   Messier 47           NGC 2422
# 47     m48   Messier 48           NGC 2548
# 48     m49   Messier 49           NGC 4472
# 49     m50   Messier 50           NGC 2323
# 50     m51   Messier 51  NGC 5194 NGC 5195
# 51     m52   Messier 52           NGC 7654
# 52     m53   Messier 53           NGC 5024
# 53     m54   Messier 54           NGC 6715
# 54     m55   Messier 55           NGC 6809
# 55     m56   Messier 56           NGC 6779
# 56     m57   Messier 57           NGC 6720
# 57     m58   Messier 58           NGC 4579
# 58     m59   Messier 59           NGC 4621
# 59     m60   Messier 60           NGC 4649
# 60     m61   Messier 61           NGC 4303
# 61     m62   Messier 62           NGC 6266
# 62     m63   Messier 63           NGC 5055
# 63     m64   Messier 64           NGC 4826
# 64     m65   Messier 65           NGC 3623
# 65     m66   Messier 66           NGC 3627
# 66     m67   Messier 67           NGC 2682
# 67     m68   Messier 68           NGC 4590
# 68     m69   Messier 69           NGC 6637
# 69     m70   Messier 70           NGC 6681
# 70     m71   Messier 71           NGC 6838
# 71     m72   Messier 72           NGC 6981
# 72     m73   Messier 73           NGC 6994
# 73     m74   Messier 74            NGC 628
# 74     m75   Messier 75           NGC 6864
# 75     m76   Messier 76    NGC 650 NGC 651
# 76     m77   Messier 77           NGC 1068
# 77     m78   Messier 78           NGC 2068
# 78     m79   Messier 79           NGC 1904
# 79     m80   Messier 80           NGC 6093
# 80     m81   Messier 81           NGC 3031
# 81     m82   Messier 82           NGC 3034
# 82     m83   Messier 83           NGC 5236
# 83     m84   Messier 84           NGC 4374
# 84     m85   Messier 85           NGC 4382
# 85     m86   Messier 86           NGC 4406
# 86     m87   Messier 87           NGC 4486
# 87     m88   Messier 88           NGC 4501
# 88     m89   Messier 89           NGC 4552
# 89     m90   Messier 90           NGC 4569
# 90     m91   Messier 91           NGC 4548
# 91     m92   Messier 92           NGC 6341
# 92     m93   Messier 93           NGC 2447
# 93     m94   Messier 94           NGC 4736
# 94     m95   Messier 95           NGC 3351
# 95     m96   Messier 96           NGC 3368
# 96     m97   Messier 97           NGC 3587
# 97     m98   Messier 98           NGC 4192
# 98     m99   Messier 99           NGC 4254
# 99    m100  Messier 100           NGC 4321
# 100   m101  Messier 101           NGC 5457
# 101   m102  Messier 102           NGC 5866
# 102   m103  Messier 103            NGC 581
# 103   m104  Messier 104           NGC 4594
# 104   m105  Messier 105           NGC 3379
# 105   m106  Messier 106           NGC 4258
# 106   m107  Messier 107           NGC 6171
# 107   m108  Messier 108           NGC 3556
# 108   m109  Messier 109           NGC 3992
# 109   m110  Messier 110            NGC 205
#
#                                   common               type           ra  \
# 0                            Crab Nebula  supernova remnant   5h34m31.9s
# 1                                      –   globular cluster  21h33m27.2s
# 2                                      –   globular cluster  13h42m11.2s
# 3                                      –   globular cluster  16h23m35.5s
# 4                                      –   globular cluster  15h18m33.8s
# 5                      Butterfly Cluster       open cluster  17h40m20.0s
# 6                        Ptolemy Cluster       open cluster  17h53m50.0s
# 7                          Lagoon Nebula    emission nebula   18h3m42.0s
# 8                                      –   globular cluster  17h19m11.8s
# 9                                      –   globular cluster   16h57m8.9s
# 10                     Wild Duck Cluster       open cluster   18h51m5.0s
# 11                                     –   globular cluster  16h47m14.5s
# 12    Great Globular Cluster in Hercules   globular cluster  16h41m41.5s
# 13                                     –   globular cluster  17h37m36.1s
# 14                                     –   globular cluster  21h29m58.3s
# 15                          Eagle Nebula    emission nebula  18h18m45.0s
# 16   Omega Swan Horseshoe Lobster Nebula    emission nebula  18h20m47.0s
# 17                                     –       open cluster  18h19m58.0s
# 18                                     –   globular cluster   17h2m37.7s
# 19                         Trifid Nebula    emission nebula   18h2m42.0s
# 20                                     –       open cluster   18h4m13.3s
# 21                   Sagittarius Cluster   globular cluster  18h36m24.2s
# 22                                     –       open cluster  17h56m56.0s
# 23          Small Sagittarius Star Cloud         star cloud  18h18m48.0s
# 24                                     –       open cluster  18h31m45.0s
# 25                                     –       open cluster  18h45m15.0s
# 26                       Dumbbell Nebula   planetary nebula  19h59m36.3s
# 27                                     –   globular cluster  18h24m32.9s
# 28                         Cooling Tower       open cluster   20h24m6.0s
# 29                                     –   globular cluster  21h40m22.0s
# 30                      Andromeda Galaxy             galaxy   0h42m44.3s
# 31                Small Andromeda Galaxy             galaxy   0h42m41.8s
# 32            Triangulum Pinwheel Galaxy             galaxy   1h33m51.9s
# 33                                     –       open cluster    2h42m5.0s
# 34                                     –       open cluster     6h9m4.0s
# 35                                     –       open cluster   5h36m17.7s
# 36                                     –       open cluster   5h52m18.3s
# 37                      Starfish Cluster       open cluster   5h28m43.0s
# 38                                     –       open cluster  21h31m52.0s
# 39                            Winnecke-4           asterism  12h22m16.2s
# 40                                     –       open cluster    6h46m0.0s
# 41                          Orion Nebula    emission nebula   5h35m17.1s
# 42                    De Mairan's Nebula    emission nebula   5h35m31.3s
# 43              Beehive Cluster Praesepe       open cluster   8h40m24.0s
# 44                              Pleiades       open cluster    3h47m0.0s
# 45                                     –       open cluster   7h41m46.8s
# 46                                     –       open cluster   7h36m35.0s
# 47                                     –       open cluster   8h13m43.1s
# 48                                     –             galaxy  12h29m46.7s
# 49                                     –       open cluster    7h2m47.8s
# 50                      Whirlpool Galaxy             galaxy  13h29m52.6s
# 51                                     –       open cluster  23h24m48.0s
# 52                                     –   globular cluster  13h12m55.3s
# 53                                     –   globular cluster   18h55m3.3s
# 54                                     –   globular cluster  19h39m59.4s
# 55                                     –   globular cluster  19h16m35.5s
# 56                           Ring Nebula   planetary nebula  18h53m35.1s
# 57                                     –             galaxy  12h37m43.7s
# 58                                     –             galaxy   12h42m2.2s
# 59                                     –             galaxy  12h43m39.8s
# 60                                     –             galaxy  12h21m54.9s
# 61                                     –   globular cluster   17h1m12.6s
# 62                      Sunflower Galaxy             galaxy  13h15m49.0s
# 63                      Black Eye Galaxy             galaxy  12h56m43.8s
# 64                           Leo Triplet             galaxy  11h18m55.6s
# 65                           Leo Triplet             galaxy  11h20m15.1s
# 66                                     –       open cluster   8h51m18.0s
# 67                                     –   globular cluster  12h39m28.0s
# 68                                     –   globular cluster  18h31m23.2s
# 69                                     –   globular cluster  18h43m12.7s
# 70                                     –   globular cluster  19h53m46.1s
# 71                                     –   globular cluster  20h53m27.9s
# 72                                     –           asterism  20h58m56.0s
# 73                        Phantom Galaxy             galaxy   1h36m41.7s
# 74                                     –   globular cluster    20h6m4.8s
# 75                Little Dumbbell Nebula   planetary nebula   1h42m18.1s
# 76                               Cetus A             galaxy   2h42m40.8s
# 77                                     –     diffuse nebula   5h46m45.0s
# 78                                     –   globular cluster   5h24m10.6s
# 79                                     –   globular cluster   16h17m2.5s
# 80                         Bode's Galaxy             galaxy   9h55m33.5s
# 81                          Cigar Galaxy             galaxy   9h55m54.0s
# 82              Southern Pinwheel Galaxy             galaxy   13h37m0.2s
# 83                                     –             galaxy   12h25m3.6s
# 84                                     –             galaxy  12h25m23.9s
# 85                                     –             galaxy  12h26m11.5s
# 86                               Virgo A             galaxy  12h30m49.4s
# 87                                     –             galaxy  12h31m59.0s
# 88                                     –             galaxy  12h35m39.9s
# 89                                     –             galaxy  12h36m50.0s
# 90                                     –             galaxy  12h35m26.4s
# 91                                     –   globular cluster   17h17m7.3s
# 92                                     –       open cluster   7h44m30.0s
# 93               Croc's Eye or Cat's Eye             galaxy  12h50m53.1s
# 94                                     –             galaxy  10h43m57.8s
# 95                                     –             galaxy  10h46m45.8s
# 96                            Owl Nebula   planetary nebula  11h14m47.7s
# 97                                     –             galaxy  12h13m47.8s
# 98                                     –             galaxy  12h18m49.3s
# 99                                     –             galaxy  12h22m54.9s
# 100                      Pinwheel Galaxy             galaxy   14h3m12.4s
# 101                       Spindle Galaxy             galaxy   15h6m29.4s
# 102                                    –       open cluster   1h33m23.0s
# 103                      Sombrero Galaxy             galaxy  12h39m59.3s
# 104                                    –             galaxy  10h47m49.5s
# 105                                    –             galaxy  12h18m57.8s
# 106                                    –   globular cluster  16h32m31.9s
# 107                                    –             galaxy  11h11m29.4s
# 108                                    –             galaxy  11h57m35.4s
# 109                                    –             galaxy   0h40m22.1s
#
#             dec   mag        dist             con  \
# 0     +22d0m52s   8.4      6.5000          Taurus
# 1     -0d49m22s   6.6     33.0000        Aquarius
# 2    +28d22m34s   6.3     33.9000  Canes Venatici
# 3    -26d31m29s   5.4      7.2000        Scorpius
# 4       +2d5m0s   5.7     24.5000         Serpens
# 5    -32d15m30s   4.2      1.6000        Scorpius
# 6    -34d47m36s   3.3      0.9800        Scorpius
# 7    -24d22m48s   5.8      4.1000     Sagittarius
# 8    -18d30m57s   7.8     25.8000       Ophiuchus
# 9      -4d5m56s   6.6     14.3000       Ophiuchus
# 10    -6d16m12s   5.8      6.2000          Scutum
# 11    -1d56m50s   6.1     15.7000       Ophiuchus
# 12   +36d27m39s   5.8     22.2000        Hercules
# 13    -3d14m43s   7.6     30.3000       Ophiuchus
# 14    +12d10m3s   6.3     33.0000         Pegasus
# 15   -13d47m54s   6.0      7.0000         Serpens
# 16   -16d10m18s   6.0      5.5000     Sagittarius
# 17     -17d6m6s   6.9      4.9000     Sagittarius
# 18    -26d16m3s   6.8     28.7000       Ophiuchus
# 19   -22d58m18s   8.5      5.2000     Sagittarius
# 20    -22d30m0s   5.9      4.2500     Sagittarius
# 21   -23d54m10s   5.2     10.6000     Sagittarius
# 22    -19d0m42s   5.5      2.1500     Sagittarius
# 23    -18d33m0s   4.6     10.0000     Sagittarius
# 24    -19d7m12s   4.6      2.0000     Sagittarius
# 25     -9d23m6s   8.0      5.0000          Scutum
# 26   +22d43m18s   7.4      1.3340       Vulpecula
# 27   -24d52m10s   6.9     17.9000     Sagittarius
# 28   +38d29m36s   6.6      7.2000          Cygnus
# 29   -23d10m43s   6.9     29.4000     Capricornus
# 30    +41d16m8s   3.4   2540.0000       Andromeda
# 31   +40d51m57s   8.1   2490.0000       Andromeda
# 32   +30d39m29s   5.7   2725.0000      Triangulum
# 33   +42d45m42s   5.2      1.5000         Perseus
# 34    +24d21m0s   5.1      2.8000          Gemini
# 35    +34d8m27s   6.0      4.1000          Auriga
# 36   +32d33m11s   5.6      4.5110          Auriga
# 37   +35d51m18s   6.4      4.2000          Auriga
# 38   +48d25m30s   4.6      0.8244          Cygnus
# 39     +58d5m8s   9.0      0.5100      Ursa Major
# 40   -20d45m24s   4.5      2.3000     Canis Major
# 41    -5d23m25s   4.0      1.3440           Orion
# 42     -5d16m3s   6.8      1.6000           Orion
# 43   +19d40m12s   3.1      0.5770          Cancer
# 44     +24d7m0s   1.6      0.4250          Taurus
# 45   -14d48m36s   6.1      5.4000          Puppis
# 46   -14d28m47s   4.4      1.6000          Puppis
# 47     -5d45m2s   5.8      1.5000           Hydra
# 48      +8d0m0s   8.4  55900.0000           Virgo
# 49    -8d22m33s   5.9      3.2000       Monoceros
# 50   +47d11m44s   8.4  23000.0000  Canes Venatici
# 51    +61d36m0s   6.9      5.0000      Cassiopeia
# 52   +18d10m11s   7.7     58.0000  Coma Berenices
# 53   -30d28m40s   7.7     87.4000     Sagittarius
# 54   -30d57m42s   6.3     17.6000     Sagittarius
# 55    +30d11m7s   8.4     32.9000            Lyra
# 56    +33d1m47s   8.8      2.7000            Lyra
# 57    +11d49m6s   9.7  63000.0000           Virgo
# 58   +11d38m50s   9.6  60000.0000           Virgo
# 59   +11d33m11s   8.8  55000.0000           Virgo
# 60    +4d28m22s   9.7  52500.0000           Virgo
# 61    -30d6m42s   6.4     22.2000       Ophiuchus
# 62    +42d1m59s   8.6  37000.0000  Canes Venatici
# 63   +21d40m59s   8.5  24000.0000  Coma Berenices
# 64    +13d5m27s   9.3  41500.0000             Leo
# 65   +12d59m24s   8.9  36000.0000             Leo
# 66    +11d49m0s   6.9      2.7700          Cancer
# 67   -26d44m32s   7.3     33.6000           Hydra
# 68   -32d20m51s   8.3     29.7000     Sagittarius
# 69   -32d17m29s   7.8     29.4000     Sagittarius
# 70   +18d46m44s   8.4     13.0000         Sagitta
# 71   -12d32m11s   9.2     54.5700        Aquarius
# 72    -12d38m0s   8.9      2.5000        Aquarius
# 73    +15d47m0s   9.4  30000.0000          Pisces
# 74   -21d55m15s   8.6     67.5000     Sagittarius
# 75   +51d34m17s  10.1      2.5000         Perseus
# 76     -0d0m46s   8.9  47000.0000           Cetus
# 77     +0d4m48s   8.0      1.6000           Orion
# 78   -24d31m25s   7.7     41.0000           Lepus
# 79   -22d58m28s   7.3     32.6000        Scorpius
# 80     +69d4m2s   6.9  11800.0000      Ursa Major
# 81   +69d40m59s   8.4  11500.0000      Ursa Major
# 82    -29d52m2s   7.5  14700.0000           Hydra
# 83   +12d53m13s   9.1  60000.0000           Virgo
# 84   +18d11m27s   9.1  60000.0000  Coma Berenices
# 85   +12d56m47s   8.9  52000.0000           Virgo
# 86   +12d23m26s   8.6  53500.0000           Virgo
# 87   +14d25m11s   9.6  47500.0000  Coma Berenices
# 88   +12d33m22s   9.8  50000.0000           Virgo
# 89    +13d9m50s   9.5  58700.0000           Virgo
# 90   +14d29m47s  10.2  63000.0000  Coma Berenices
# 91    +43d8m13s   6.5     26.7000        Hercules
# 92   -23d51m24s   6.2      3.6000          Puppis
# 93    +41d7m17s   8.2  16000.0000  Canes Venatici
# 94   +11d42m12s   9.7  32600.0000             Leo
# 95   +11d49m12s   9.3  31000.0000             Leo
# 96    +55d1m10s   9.9      2.0300      Ursa Major
# 97   +14d53m58s  10.1  44400.0000  Coma Berenices
# 98    +14d25m3s   9.9  50200.0000  Coma Berenices
# 99   +15d49m22s   9.4  55000.0000  Coma Berenices
# 100  +54d20m58s   7.9  20750.0000      Ursa Major
# 101  +55d45m49s   9.9  50000.0000           Draco
# 102  +60d39m30s   7.4     10.0000      Cassiopeia
# 103  -11d37m21s   8.0  29800.0000           Virgo
# 104  +12d34m52s   9.3  32000.0000             Leo
# 105  +47d18m25s   8.4  23700.0000  Canes Venatici
# 106   -13d3m11s   7.8     20.9000       Ophiuchus
# 107  +55d40m22s  10.0  46000.0000      Ursa Major
# 108  +53d22m25s   9.8  83500.0000      Ursa Major
# 109   +41d41m7s   8.1   2690.0000       Andromeda
#
#                                                  image
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# 5    https://upload.wikimedia.org/wikipedia/commons...
# 6    https://upload.wikimedia.org/wikipedia/commons...
# 7    https://upload.wikimedia.org/wikipedia/commons...
# 8    https://upload.wikimedia.org/wikipedia/commons...
# 9    https://upload.wikimedia.org/wikipedia/commons...
# 10   https://upload.wikimedia.org/wikipedia/commons...
# 11   https://upload.wikimedia.org/wikipedia/commons...
# 12   https://upload.wikimedia.org/wikipedia/commons...
# 13   https://upload.wikimedia.org/wikipedia/commons...
# 14   https://upload.wikimedia.org/wikipedia/commons...
# 15   https://upload.wikimedia.org/wikipedia/commons...
# 16   https://upload.wikimedia.org/wikipedia/commons...
# 17   https://upload.wikimedia.org/wikipedia/commons...
# 18   https://upload.wikimedia.org/wikipedia/commons...
# 19   https://upload.wikimedia.org/wikipedia/commons...
# 20   https://upload.wikimedia.org/wikipedia/commons...
# 21   https://upload.wikimedia.org/wikipedia/commons...
# 22   https://upload.wikimedia.org/wikipedia/commons...
# 23   https://upload.wikimedia.org/wikipedia/commons...
# 24   https://upload.wikimedia.org/wikipedia/commons...
# 25   https://upload.wikimedia.org/wikipedia/commons...
# 26   https://upload.wikimedia.org/wikipedia/commons...
# 27   https://upload.wikimedia.org/wikipedia/commons...
# 28   https://upload.wikimedia.org/wikipedia/commons...
# 29   https://upload.wikimedia.org/wikipedia/commons...
# 30   https://upload.wikimedia.org/wikipedia/commons...
# 31   https://upload.wikimedia.org/wikipedia/commons...
# 32   https://upload.wikimedia.org/wikipedia/commons...
# 33   https://upload.wikimedia.org/wikipedia/commons...
# 34   https://upload.wikimedia.org/wikipedia/commons...
# 35   https://upload.wikimedia.org/wikipedia/commons...
# 36   https://upload.wikimedia.org/wikipedia/commons...
# 37   https://upload.wikimedia.org/wikipedia/commons...
# 38   https://upload.wikimedia.org/wikipedia/commons...
# 39   https://upload.wikimedia.org/wikipedia/commons...
# 40   https://upload.wikimedia.org/wikipedia/commons...
# 41   https://upload.wikimedia.org/wikipedia/commons...
# 42   https://upload.wikimedia.org/wikipedia/commons...
# 43   https://upload.wikimedia.org/wikipedia/commons...
# 44   https://upload.wikimedia.org/wikipedia/commons...
# 45   https://upload.wikimedia.org/wikipedia/commons...
# 46   https://upload.wikimedia.org/wikipedia/commons...
# 47   https://upload.wikimedia.org/wikipedia/commons...
# 48   https://upload.wikimedia.org/wikipedia/commons...
# 49   https://upload.wikimedia.org/wikipedia/commons...
# 50   https://upload.wikimedia.org/wikipedia/commons...
# 51   https://upload.wikimedia.org/wikipedia/commons...
# 52   https://upload.wikimedia.org/wikipedia/commons...
# 53   https://upload.wikimedia.org/wikipedia/commons...
# 54   https://upload.wikimedia.org/wikipedia/commons...
# 55   https://upload.wikimedia.org/wikipedia/commons...
# 56   https://upload.wikimedia.org/wikipedia/commons...
# 57   https://upload.wikimedia.org/wikipedia/commons...
# 58   https://upload.wikimedia.org/wikipedia/commons...
# 59   https://upload.wikimedia.org/wikipedia/commons...
# 60   https://upload.wikimedia.org/wikipedia/commons...
# 61   https://upload.wikimedia.org/wikipedia/commons...
# 62   https://upload.wikimedia.org/wikipedia/commons...
# 63   https://upload.wikimedia.org/wikipedia/commons...
# 64   https://upload.wikimedia.org/wikipedia/commons...
# 65   https://upload.wikimedia.org/wikipedia/commons...
# 66   https://upload.wikimedia.org/wikipedia/commons...
# 67   https://upload.wikimedia.org/wikipedia/commons...
# 68   https://upload.wikimedia.org/wikipedia/commons...
# 69   https://upload.wikimedia.org/wikipedia/commons...
# 70   https://upload.wikimedia.org/wikipedia/commons...
# 71   https://upload.wikimedia.org/wikipedia/commons...
# 72   https://upload.wikimedia.org/wikipedia/commons...
# 73   https://upload.wikimedia.org/wikipedia/commons...
# 74   https://upload.wikimedia.org/wikipedia/commons...
# 75   https://upload.wikimedia.org/wikipedia/commons...
# 76   https://upload.wikimedia.org/wikipedia/commons...
# 77   https://upload.wikimedia.org/wikipedia/commons...
# 78   https://upload.wikimedia.org/wikipedia/commons...
# 79   https://upload.wikimedia.org/wikipedia/commons...
# 80   https://upload.wikimedia.org/wikipedia/commons...
# 81   https://upload.wikimedia.org/wikipedia/commons...
# 82   https://upload.wikimedia.org/wikipedia/commons...
# 83   https://upload.wikimedia.org/wikipedia/commons...
# 84   https://upload.wikimedia.org/wikipedia/commons...
# 85   https://upload.wikimedia.org/wikipedia/commons...
# 86   https://upload.wikimedia.org/wikipedia/commons...
# 87   https://upload.wikimedia.org/wikipedia/commons...
# 88   https://upload.wikimedia.org/wikipedia/commons...
# 89   https://upload.wikimedia.org/wikipedia/commons...
# 90   https://upload.wikimedia.org/wikipedia/commons...
# 91   https://upload.wikimedia.org/wikipedia/commons...
# 92   https://upload.wikimedia.org/wikipedia/commons...
# 93   https://upload.wikimedia.org/wikipedia/commons...
# 94   https://upload.wikimedia.org/wikipedia/commons...
# 95   https://upload.wikimedia.org/wikipedia/commons...
# 96   https://upload.wikimedia.org/wikipedia/commons...
# 97   https://upload.wikimedia.org/wikipedia/commons...
# 98   https://upload.wikimedia.org/wikipedia/commons...
# 99   https://upload.wikimedia.org/wikipedia/commons...
# 100  https://upload.wikimedia.org/wikipedia/commons...
# 101  https://upload.wikimedia.org/wikipedia/commons...
# 102  https://upload.wikimedia.org/wikipedia/commons...
# 103  https://upload.wikimedia.org/wikipedia/commons...
# 104  https://upload.wikimedia.org/wikipedia/commons...
# 105  https://upload.wikimedia.org/wikipedia/commons...
# 106  https://upload.wikimedia.org/wikipedia/commons...
# 107  https://upload.wikimedia.org/wikipedia/commons...
# 108  https://upload.wikimedia.org/wikipedia/commons...
# 109  https://upload.wikimedia.org/wikipedia/commons...

# %% [markdown]
# ### "Load"
# Not a true load in the ETL process. The loading will be done in a separate Flask app instead.

# %%
complete_messier.to_csv('complete_messier.csv', index=False, header=False)

# %%
# complete_messier.to_csv('complete_messier_with_header.csv', index=False)
