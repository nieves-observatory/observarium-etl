# %% [markdown]
# # Adding Caldwell Catalogue

# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %% [markdown]
# Add:
# 1. Raw list from wikipedia
# 1. Images
# 1. Dec RA from NGC/IC catalogue
# 1. params
# 1. Rename types

# %%
caldwell_df = pd.read_csv('raw_data/caldwell_raw.csv') 
caldwell_df = caldwell_df[:-1]
del caldwell_df['Image']
caldwell_df.at[13, "NGC number"] = "NGC 869"
caldwell_df.rename({"Caldwell number": "params", "NGC number": "ngcic", "Distance(1000 ly)": "dist", "Common name": "common"}, axis=1, inplace=True)
caldwell_df = caldwell_df.fillna('-')
caldwell_df.head()
# Out:
#   params     ngcic          common                     Type    dist  \
# 0     C1   NGC 188               -             Open Cluster     4.8
# 1     C2    NGC 40  Bow-Tie Nebula         Planetary Nebula     3.5
# 2     C3  NGC 4236               -     Barred Spiral Galaxy   7,000
# 3     C4  NGC 7023     Iris Nebula  Open Cluster and Nebula     1.4
# 4     C5    IC 342   Hidden Galaxy            Spiral Galaxy  10,000
#
#     Constellation Magnitude
# 0         Cepheus       8.1
# 1         Cepheus        11
# 2           Draco       9.7
# 3         Cepheus         7
# 4  Camelopardalis         9

# %%
for i in range(len(caldwell_df.Type)):
    if caldwell_df["Type"][i].find("Galaxy") != -1:
        caldwell_df["Type"][i] = "Galaxy"
    if caldwell_df["Type"][i] == "Nebula":
        caldwell_df["Type"][i] = "Emission nebula"
    if caldwell_df["Type"][i] == "Open Cluster and Nebula":
        caldwell_df["Type"][i] = "Open Cluster"
        
caldwell_df.head()
# Out:
#   params     ngcic          common              Type    dist   Constellation  \
# 0     C1   NGC 188               -      Open Cluster     4.8         Cepheus
# 1     C2    NGC 40  Bow-Tie Nebula  Planetary Nebula     3.5         Cepheus
# 2     C3  NGC 4236               -            Galaxy   7,000           Draco
# 3     C4  NGC 7023     Iris Nebula      Open Cluster     1.4         Cepheus
# 4     C5    IC 342   Hidden Galaxy            Galaxy  10,000  Camelopardalis
#
#   Magnitude
# 0       8.1
# 1        11
# 2       9.7
# 3         7
# 4         9

# %%
html = urlopen('https://en.wikipedia.org/wiki/Caldwell_catalogue')
bs = BeautifulSoup(html, 'html.parser')
images = bs.find_all('img', {'src':re.compile(r'(jpg|png|jpeg)')} )

all_images = []

for image in images: 
    bigger_image = image['src'].replace("60px","500px").replace("//","")
    all_images.append("https://" + bigger_image)

all_images.pop(0)
all_images.pop(0)
all_images.pop(0)
all_images.pop(0)
all_images.pop(0)
all_images.pop(0)
all_images.pop(0)

all_images.pop()
all_images.pop()
all_images.pop()
all_images.pop()
all_images.pop()
all_images.pop()

all_images.insert(61,"https://upload.wikimedia.org/wikipedia/commons/thumb/a/a8/Wide_Field_Imager_view_of_the_spiral_galaxy_NGC_247.jpg/500px-Wide_Field_Imager_view_of_the_spiral_galaxy_NGC_247.jpg")

# %%
image_df = pd.DataFrame(all_images, columns =['image'])
image_df.head()
# Out:
#                                                image
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...

# %%
caldwell_coords = pd.read_csv('raw_data/caldwell_coords_clean.csv') 
caldwell_coords.head()
# Out:
#    C     NGC Type   Mag   Size Distance (ly)       RA     Dec  Con  \
# 0  1     188   Oc   8.1     14          4800  00 44.4  +85 20  Cep
# 1  2      40   Pl  11.6    0.6          3500  00 13.0  +72 32  Cep
# 2  3    4236   Sb   9.7   21x7     7 million  12 16.7  +69 28  Dra
# 3  4    7023   Bn   6.8  18x18          1400  21 01.8  +68 12  Cep
# 4  5  IC 342   Sp   9.2  18x17    13 million  03 46.8  +68 06  Cam
#
#   Viewing Season
# 0         autumn
# 1         autumn
# 2         spring
# 3         autumn
# 4         winter

# %%
example_str = caldwell_coords["Dec"][0]
example_str[4:6]
# Out:
# '20'

# %%
caldwell_dec = []

for x in caldwell_coords["Dec"]:
    degree = x[0:3]+"d"
    arcmin = x[4:6]+"m"
    arcsec = "00s"
    caldwell_dec.append(degree+arcmin+arcsec)

# %%
caldwell_ra = []

for x in caldwell_coords["RA"]:
    hours = x[0:2]+"h"
    mins = x[3:5]+"m"
    seconds = str(float("0" + x[5:7])*60)+"s"
    caldwell_ra.append(hours+mins+seconds)

# caldwell_ra

# %%
ra_df = pd.DataFrame(caldwell_ra, columns =['ra'])
dec_df = pd.DataFrame(caldwell_dec, columns =['dec'])
caldwell_coords_processed = pd.concat([ra_df.reset_index(drop=True),dec_df.reset_index(drop=True)],axis=1)
caldwell_coords_processed.head()
# Out:
#             ra         dec
# 0  00h44m24.0s  +85d20m00s
# 1   00h13m0.0s  +72d32m00s
# 2  12h16m42.0s  +69d28m00s
# 3  21h01m48.0s  +68d12m00s
# 4  03h46m48.0s  +68d06m00s

# %% [markdown]
# Add name

# %%
name_list = ["Caldwell " + str(i+1) for i in range(109)]
name_df = pd.DataFrame(name_list, columns =['name'])
# name_df

# %%
caldwell_with_coords = pd.concat([caldwell_df.reset_index(drop=True),caldwell_coords_processed.reset_index(drop=True)],axis=1)
caldwell_with_names = pd.concat([caldwell_with_coords.reset_index(drop=True),name_df.reset_index(drop=True)],axis=1)
complete_caldwell = pd.concat([caldwell_with_names.reset_index(drop=True),image_df.reset_index(drop=True)],axis=1)

complete_caldwell = complete_caldwell[["params", "name", "ngcic", "common", "Type", "ra", "dec", "Magnitude", "dist", "Constellation", "image"]]
complete_caldwell.loc[complete_caldwell.shape[0]] = ['sh2248', 'Sharpless 248', 'IC 443', 'Jellyfish Nebula', 'Supernova remnant', '06h17m13s', '+22d31m05s', 12, 5, 'Gemini', 'https://upload.wikimedia.org/wikipedia/commons/7/78/IC443.jpeg']

# %%
complete_caldwell.head()
# Out:
#   params        name     ngcic          common              Type           ra  \
# 0     C1  Caldwell 1   NGC 188               -      Open Cluster  00h44m24.0s
# 1     C2  Caldwell 2    NGC 40  Bow-Tie Nebula  Planetary Nebula   00h13m0.0s
# 2     C3  Caldwell 3  NGC 4236               -            Galaxy  12h16m42.0s
# 3     C4  Caldwell 4  NGC 7023     Iris Nebula      Open Cluster  21h01m48.0s
# 4     C5  Caldwell 5    IC 342   Hidden Galaxy            Galaxy  03h46m48.0s
#
#           dec Magnitude    dist   Constellation  \
# 0  +85d20m00s       8.1     4.8         Cepheus
# 1  +72d32m00s        11     3.5         Cepheus
# 2  +69d28m00s       9.7   7,000           Draco
# 3  +68d12m00s         7     1.4         Cepheus
# 4  +68d06m00s         9  10,000  Camelopardalis
#
#                                                image
# 0  https://upload.wikimedia.org/wikipedia/commons...
# 1  https://upload.wikimedia.org/wikipedia/commons...
# 2  https://upload.wikimedia.org/wikipedia/commons...
# 3  https://upload.wikimedia.org/wikipedia/commons...
# 4  https://upload.wikimedia.org/wikipedia/commons...

# %% [markdown]
# Final process

# %%
for i in range(len(complete_caldwell.params)):
    complete_caldwell.params[i] = complete_caldwell.params[i].lower()
    
for i in range(len(complete_caldwell.Type)):
    complete_caldwell.Type[i] = complete_caldwell.Type[i].capitalize()
    
for i in range(len(complete_caldwell.common)):
    complete_caldwell.common[i] = complete_caldwell.common[i].replace(",", " ")
    
for i in range(len(complete_caldwell.dist)):
    complete_caldwell.dist[i] = complete_caldwell.dist[i].replace(",", "")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-210-9202ddd063fb> in <module>
#       9
#      10 for i in range(len(complete_caldwell.dist)):
# ---> 11     complete_caldwell.dist[i] = complete_caldwell.dist[i].replace(",", "")
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
complete_caldwell
# Out:
#      params           name     ngcic                           common  \
# 0        c1     Caldwell 1   NGC 188                                -
# 1        c2     Caldwell 2    NGC 40                   Bow-Tie Nebula
# 2        c3     Caldwell 3  NGC 4236                                -
# 3        c4     Caldwell 4  NGC 7023                      Iris Nebula
# 4        c5     Caldwell 5    IC 342                    Hidden Galaxy
# 5        c6     Caldwell 6  NGC 6543                 Cat's Eye Nebula
# 6        c7     Caldwell 7  NGC 2403                                -
# 7        c8     Caldwell 8   NGC 559                                -
# 8        c9     Caldwell 9   Sh2-155                      Cave Nebula
# 9       c10    Caldwell 10   NGC 663                                -
# 10      c11    Caldwell 11  NGC 7635                    Bubble Nebula
# 11      c12    Caldwell 12  NGC 6946                 Fireworks Galaxy
# 12      c13    Caldwell 13   NGC 457        Owl Cluster  E.T. Cluster
# 13      c14    Caldwell 14   NGC 869     Double Cluster  h & χ Persei
# 14      c15    Caldwell 15  NGC 6826               Blinking Planetary
# 15      c16    Caldwell 16  NGC 7243                                -
# 16      c17    Caldwell 17   NGC 147                                -
# 17      c18    Caldwell 18   NGC 185                                -
# 18      c19    Caldwell 19   IC 5146                    Cocoon Nebula
# 19      c20    Caldwell 20  NGC 7000             North America Nebula
# 20      c21    Caldwell 21  NGC 4449                                -
# 21      c22    Caldwell 22  NGC 7662                    Blue Snowball
# 22      c23    Caldwell 23   NGC 891             Silver Sliver Galaxy
# 23      c24    Caldwell 24  NGC 1275                        Perseus A
# 24      c25    Caldwell 25  NGC 2419                                -
# 25      c26    Caldwell 26  NGC 4244                                -
# 26      c27    Caldwell 27  NGC 6888                  Crescent Nebula
# 27      c28    Caldwell 28   NGC 752                                -
# 28      c29    Caldwell 29  NGC 5005                                -
# 29      c30    Caldwell 30  NGC 7331                                -
# 30      c31    Caldwell 31    IC 405              Flaming Star Nebula
# 31      c32    Caldwell 32  NGC 4631                     Whale Galaxy
# 32      c33    Caldwell 33  NGC 6992                 East Veil Nebula
# 33      c34    Caldwell 34  NGC 6960                 West Veil Nebula
# 34      c35    Caldwell 35  NGC 4889                           Coma B
# 35      c36    Caldwell 36  NGC 4559                                -
# 36      c37    Caldwell 37  NGC 6885                                -
# 37      c38    Caldwell 38  NGC 4565                    Needle Galaxy
# 38      c39    Caldwell 39  NGC 2392  Eskimo Nebula/Clown Face Nebula
# 39      c40    Caldwell 40  NGC 3626                                -
# 40      c41    Caldwell 41    Mel 25                           Hyades
# 96      c97    Caldwell 97  NGC 3766                    Pearl Cluster
# 97      c98    Caldwell 98  NGC 4609                                -
# 98      c99    Caldwell 99         -                  Coalsack Nebula
# 99     c100   Caldwell 100   IC 2944           Lambda Centauri Nebula
# 100    c101   Caldwell 101  NGC 6744                                -
# 101    c102   Caldwell 102   IC 2602                Theta Car Cluster
# 102    c103   Caldwell 103  NGC 2070                 Tarantula Nebula
# 103    c104   Caldwell 104   NGC 362                                -
# 104    c105   Caldwell 105  NGC 4833                                -
# 105    c106   Caldwell 106   NGC 104                       47 Tucanae
# 106    c107   Caldwell 107  NGC 6101                                -
# 107    c108   Caldwell 108  NGC 4372                                -
# 108    c109   Caldwell 109  NGC 3195                                -
# 109  sh2248  Sharpless 248    IC 443                 Jellyfish Nebula
#
#                   Type           ra         dec Magnitude    dist  \
# 0         Open cluster  00h44m24.0s  +85d20m00s       8.1     4.8
# 1     Planetary nebula   00h13m0.0s  +72d32m00s        11     3.5
# 2               Galaxy  12h16m42.0s  +69d28m00s       9.7    7000
# 3         Open cluster  21h01m48.0s  +68d12m00s         7     1.4
# 4               Galaxy  03h46m48.0s  +68d06m00s         9   10000
# 5     Planetary nebula  17h58m36.0s  +66d38m00s         9       3
# 6               Galaxy  07h36m54.0s  +65d36m00s       8.4   14000
# 7         Open cluster  01h29m30.0s  +63d18m00s       9.5     3.7
# 8      Emission nebula  22h56m48.0s  +62d37m00s       7.7     2.8
# 9         Open cluster   01h46m0.0s  +61d15m00s       7.1     7.2
# 10     Emission nebula  23h20m42.0s  +61d12m00s        10     7.1
# 11              Galaxy  20h34m48.0s  +60d09m00s       8.9   18000
# 12        Open cluster   01h19m6.0s  +58d20m00s       6.4       -
# 13        Open cluster   02h20m0.0s  +57d08m00s         4     7.3
# 14    Planetary nebula  19h44m48.0s  +50d31m00s        10     2.2
# 15        Open cluster  22h15m18.0s  +49d53m00s       6.4     2.5
# 16              Galaxy  00h33m12.0s  +48d30m00s       9.3    2300
# 17              Galaxy   00h39m0.0s  +48d20m00s       9.2    2300
# 18        Open cluster  21h53m30.0s  +47d16m00s       7.2     3.3
# 19     Emission nebula  20h58m48.0s  +44d20m00s         4     2.6
# 20              Galaxy  12h28m12.0s  +44d06m00s       9.4   10000
# 21    Planetary nebula  23h25m54.0s  +42d33m00s         9     3.2
# 22              Galaxy  02h22m36.0s  +42d21m00s        10   31000
# 23              Galaxy  03h19m48.0s  +41d31m00s      11.6  230000
# 24    Globular cluster   07h38m6.0s  +38d53m00s      10.4     275
# 25              Galaxy  12h17m30.0s  +37d49m00s      10.2   10000
# 26     Emission nebula   20h12m0.0s  +38d21m00s       7.4     4.7
# 27        Open cluster  01h57m48.0s  +37d41m00s       5.7     1.2
# 28              Galaxy  13h10m54.0s  +37d03m00s       9.8   69000
# 29              Galaxy   22h37m6.0s  +34d25m00s       9.5   47000
# 30     Emission nebula  05h16m12.0s  +34d16m00s        13     1.6
# 31              Galaxy   12h42m6.0s  +32d32m00s       9.3   22000
# 32   Supernova remnant  20h56m24.0s  +31d43m00s         7     2.5
# 33   Supernova remnant  20h45m42.0s  +30d43m00s         7     2.5
# 34              Galaxy   13h00m6.0s  +27d59m00s      11.4  300000
# 35              Galaxy   12h36m0.0s  +27d58m00s       9.9   32000
# 36        Open cluster   20h12m0.0s  +26d29m00s         6    1.95
# 37              Galaxy  12h36m18.0s  +25d59m00s       9.6   32000
# 38    Planetary nebula  07h29m12.0s  +20d55m00s        10       4
# 39              Galaxy   11h20m6.0s  +18d21m00s      10.9   86000
# 40        Open cluster   04h27m0.0s  +16d00m00s       0.5   0.151
# 41    Globular cluster  21h01m30.0s  +16d11m00s      10.6     135
# 42              Galaxy  00h03m18.0s  +16d09m00s      10.5   49000
# 43              Galaxy  23h04m54.0s  +12d19m00s        11  106000
# 44              Galaxy  13h37m30.0s  +08d53m00s      10.2   74000
# 45     Emission nebula  06h39m12.0s  +08d44m00s         -     2.5
# 46    Globular cluster  20h34m12.0s  +07d24m00s       8.9      57
# 47              Galaxy  09h10m18.0s  +07d02m00s      10.3   55000
# 48     Emission nebula  06h32m18.0s  +05d03m00s       9.0     4.9
# 49        Open cluster  06h32m24.0s  +04d52m00s       4.8     4.9
# 50              Galaxy  01h04m48.0s  +02d07m00s       9.3    2300
# 51              Galaxy  12h48m36.0s  -05d48m00s       9.3   76000
# 52              Galaxy  10h05m12.0s  -07d43m00s       9.2   22000
# 53        Open cluster  08h00m12.0s  -10d47m00s       7.6      10
# 54    Planetary nebula  21h04m12.0s  -11d22m00s         8     1.4
# 55    Planetary nebula   00h47m0.0s  -11d53m00s         8     1.6
# 56              Galaxy  19h44m54.0s  -14d48m00s         9    2300
# 57        Open cluster  07h17m48.0s  -15d37m00s       7.2     3.7
# 58    Planetary nebula  10h24m48.0s  -18d38m00s         9     1.4
# 59              Galaxy  12h01m54.0s  -18d52m00s      10.7   83000
# 60              Galaxy  12h01m54.0s  -18d53m00s        13   83000
# 61              Galaxy   00h47m6.0s  -20d46m00s       8.9    6800
# 62    Planetary nebula  22h29m36.0s  -20d48m00s       7.3   0.522
# 63        Open cluster  07h18m48.0s  -24d57m00s       4.1     5.1
# 64              Galaxy  00h47m36.0s  -25d17m00s       7.1    9800
# 65    Globular cluster  14h39m36.0s  -26d32m00s      10.2     113
# 66              Galaxy  02h46m18.0s  -30d17m00s       9.3   47000
# 67     Emission nebula  19h01m54.0s  -36d57m00s         -   0.424
# 68    Planetary nebula  17h13m42.0s  -37d06m00s        13     5.2
# 69              Galaxy  00h54m54.0s  -37d41m00s         9    3900
# 70        Open cluster  07h52m18.0s  -38d33m00s       5.8     3.7
# 71              Galaxy  00h14m54.0s  -39d11m00s         8    4200
# 72    Globular cluster   05h14m6.0s  -40d03m00s       7.3    39.4
# 73    Planetary nebula  10h07m42.0s  -40d26m00s         8       2
# 74        Open cluster  16h25m36.0s  -40d40m00s       5.8     1.5
# 75        Open cluster   16h54m0.0s  -41d48m00s       2.6       6
# 76              Galaxy  13h25m30.0s  -43d01m00s         7   16000
# 77    Globular cluster   18h08m0.0s  -43d42m00s       6.6    22.3
# 78    Globular cluster  10h17m36.0s  -46d25m00s       6.8      17
# 79    Globular cluster  13h26m48.0s  -47d29m00s       3.7    17.3
# 80    Globular cluster  17h25m30.0s  -48d25m00s       8.2    18.6
# 81        Open cluster  16h41m18.0s  -48d46m00s       5.2     4.3
# 82              Galaxy  13h05m24.0s  -49d28m00s         9   17000
# 83    Globular cluster  13h46m24.0s  -51d22m00s       7.6      36
# 84        Open cluster  08h40m12.0s  -53d04m00s       2.5     0.5
# 85    Globular cluster  17h40m42.0s  -53d40m00s       5.7     7.5
# 86    Globular cluster  03h12m18.0s  -55d13m00s       8.4    55.5
# 87        Open cluster  15h05m42.0s  -55d36m00s       7.9     3.4
# 88        Open cluster  16h18m54.0s  -57d54m00s       5.4     3.3
# 89    Planetary nebula  09h21m24.0s  -58d19m00s        10     5.5
# 90        Open cluster  11h06m24.0s  -58d40m00s         3     1.6
# 91     Emission nebula  10h43m48.0s  -59d52m00s         3     7.5
# 92    Globular cluster  19h10m54.0s  -59d59m00s       5.4      13
# 93        Open cluster  12h53m36.0s  -60d20m00s       4.2     4.9
# 94        Open cluster  16h03m42.0s  -60d30m00s       5.1     2.5
# 95        Open cluster  07h58m18.0s  -60d52m00s       3.8     1.3
# 96        Open cluster   11h36m6.0s  -61d37m00s       5.3     5.8
# 97        Open cluster  12h42m18.0s  -62d58m00s       6.9     4.2
# 98         Dark nebula   12h53m0.0s  -63d00m00s         -    0.61
# 99        Open cluster  11h36m36.0s  -63d02m00s       4.5       6
# 100             Galaxy  19h09m48.0s  -63d51m00s         9   34000
# 101       Open cluster  10h43m12.0s  -64d24m00s       1.9   0.492
# 102       Open cluster  05h38m42.0s  -69d06m00s       8.2     170
# 103   Globular cluster  01h03m12.0s  -70d51m00s       6.6    27.7
# 104   Globular cluster  12h59m36.0s  -70d53m00s       7.4    19.6
# 105   Globular cluster   00h24m6.0s  -72d05m00s         4    14.7
# 106   Globular cluster  16h25m48.0s  -72d12m00s       9.3    49.9
# 107   Globular cluster  12h25m48.0s  -72d40m00s       7.8    18.9
# 108   Planetary nebula  10h09m30.0s  -80d52m00s      11.6     5.4
# 109  Supernova remnant    06h17m13s  +22d31m05s        12       5
#
#            Constellation                                              image
# 0                Cepheus  https://upload.wikimedia.org/wikipedia/commons...
# 1                Cepheus  https://upload.wikimedia.org/wikipedia/commons...
# 2                  Draco  https://upload.wikimedia.org/wikipedia/commons...
# 3                Cepheus  https://upload.wikimedia.org/wikipedia/commons...
# 4         Camelopardalis  https://upload.wikimedia.org/wikipedia/commons...
# 5                  Draco  https://upload.wikimedia.org/wikipedia/commons...
# 6         Camelopardalis  https://upload.wikimedia.org/wikipedia/commons...
# 7             Cassiopeia  https://upload.wikimedia.org/wikipedia/commons...
# 8                Cepheus  https://upload.wikimedia.org/wikipedia/commons...
# 9             Cassiopeia  https://upload.wikimedia.org/wikipedia/commons...
# 10            Cassiopeia  https://upload.wikimedia.org/wikipedia/commons...
# 11               Cepheus  https://upload.wikimedia.org/wikipedia/commons...
# 12            Cassiopeia  https://upload.wikimedia.org/wikipedia/commons...
# 13               Perseus  https://upload.wikimedia.org/wikipedia/commons...
# 14                Cygnus  https://upload.wikimedia.org/wikipedia/commons...
# 15               Lacerta  https://upload.wikimedia.org/wikipedia/commons...
# 63           Canis Major  https://upload.wikimedia.org/wikipedia/commons...
# 64              Sculptor  https://upload.wikimedia.org/wikipedia/commons...
# 65                 Hydra  https://upload.wikimedia.org/wikipedia/commons...
# 66                Fornax  https://upload.wikimedia.org/wikipedia/commons...
# 67      Corona Australis  https://upload.wikimedia.org/wikipedia/commons...
# 68              Scorpius  https://upload.wikimedia.org/wikipedia/commons...
# 69              Sculptor  https://upload.wikimedia.org/wikipedia/commons...
# 70                Puppis  https://upload.wikimedia.org/wikipedia/commons...
# 71              Sculptor  https://upload.wikimedia.org/wikipedia/commons...
# 72               Columba  https://upload.wikimedia.org/wikipedia/commons...
# 73                  Vela  https://upload.wikimedia.org/wikipedia/commons...
# 74              Scorpius  https://upload.wikimedia.org/wikipedia/commons...
# 75              Scorpius  https://upload.wikimedia.org/wikipedia/commons...
# 76             Centaurus  https://upload.wikimedia.org/wikipedia/commons...
# 77      Corona Australis  https://upload.wikimedia.org/wikipedia/commons...
# 78                  Vela  https://upload.wikimedia.org/wikipedia/commons...
# 79             Centaurus  https://upload.wikimedia.org/wikipedia/commons...
# 80                   Ara  https://upload.wikimedia.org/wikipedia/commons...
# 81                   Ara  https://upload.wikimedia.org/wikipedia/commons...
# 82             Centaurus  https://upload.wikimedia.org/wikipedia/commons...
# 83             Centaurus  https://upload.wikimedia.org/wikipedia/commons...
# 84                  Vela  https://upload.wikimedia.org/wikipedia/commons...
# 85                   Ara  https://upload.wikimedia.org/wikipedia/commons...
# 86            Horologium  https://upload.wikimedia.org/wikipedia/commons...
# 87              Circinus  https://upload.wikimedia.org/wikipedia/commons...
# 88                 Norma  https://upload.wikimedia.org/wikipedia/commons...
# 89                Carina  https://upload.wikimedia.org/wikipedia/commons...
# 90                Carina  https://upload.wikimedia.org/wikipedia/commons...
# 91                Carina  https://upload.wikimedia.org/wikipedia/commons...
# 92                  Pavo  https://upload.wikimedia.org/wikipedia/commons...
# 93                  Crux  https://upload.wikimedia.org/wikipedia/commons...
# 94   Triangulum Australe  https://upload.wikimedia.org/wikipedia/commons...
# 95                Carina  https://upload.wikimedia.org/wikipedia/commons...
# 96             Centaurus  https://upload.wikimedia.org/wikipedia/commons...
# 97                  Crux  https://upload.wikimedia.org/wikipedia/commons...
# 98                  Crux  https://upload.wikimedia.org/wikipedia/commons...
# 99             Centaurus  https://upload.wikimedia.org/wikipedia/commons...
# 100                 Pavo  https://upload.wikimedia.org/wikipedia/commons...
# 101               Carina  https://upload.wikimedia.org/wikipedia/commons...
# 102               Dorado  https://upload.wikimedia.org/wikipedia/commons...
# 103               Tucana  https://upload.wikimedia.org/wikipedia/commons...
# 104                Musca  https://upload.wikimedia.org/wikipedia/commons...
# 105               Tucana  https://upload.wikimedia.org/wikipedia/commons...
# 106                 Apus  https://upload.wikimedia.org/wikipedia/commons...
# 107                Musca  https://upload.wikimedia.org/wikipedia/commons...
# 108           Chamaeleon  https://upload.wikimedia.org/wikipedia/commons...
# 109               Gemini  https://upload.wikimedia.org/wikipedia/commons...

# %% [markdown]
# Load time!

# %%
complete_caldwell.to_csv('complete_caldwell.csv', index=False, header=False)
